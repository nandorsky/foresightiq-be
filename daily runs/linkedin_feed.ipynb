# %%
print("Starting linkedin feed script...")
# Out:
# Starting linkedin feed script...

# %% [markdown]
# # Setup

# %%
from dotenv import load_dotenv
load_dotenv()

import requests
import json
import pandas as pd
import anthropic
import pyperclip
from supabase import create_client, Client
import time
import math
from time import perf_counter
from urllib.parse import urlparse, urlunparse, parse_qsl, urlencode
import asyncio
import aiohttp

# Supabase API
SUPABASE_URL = os.environ["SUPABASE_URL"]
SUPABASE_KEY = os.environ["SUPABASE_KEY"]
SERVICE_ROLE_KEY = os.environ["SUPABASE_SERVICE_ROLE_KEY"]

supabase: Client = create_client(SUPABASE_URL, SERVICE_ROLE_KEY)

anthropic_api_key = os.environ["ANTHROPIC_API_KEY"]
client = anthropic.Anthropic(
    api_key=anthropic_api_key,
)

# %%
# ✅ Function to Fetch Data from Supabase
def fetch_data(table_name, batch_size=500, filters=None, related_tables=None):
    try:
        all_data = []
        start = 0

        # Build select string
        if related_tables:
            select_string = "*, " + ", ".join(f"{tbl}(*)" for tbl in related_tables)
        else:
            select_string = "*"

        while True:
            query = supabase.table(table_name).select(select_string)
            
            if filters:
                for column, value in filters.items():
                    if isinstance(value, list):
                        query = query.in_(column, value)
                    elif value is None:
                        query = query.is_(column, None)
                    else:
                        query = query.eq(column, value)
            
            response = query.range(start, start + batch_size - 1).execute()
            
            if response.data:
                all_data.extend(response.data)
                start += batch_size
                if len(response.data) < batch_size:
                    break
            else:
                break

        if all_data:
            print(f"✅ Successfully fetched `{table_name}` table with filter '{filters}' and {len(all_data)} rows.")
            return pd.DataFrame(all_data)
        else:
            print(f"⚠️ `{table_name}` is empty.")
            return pd.DataFrame()

    except Exception as e:
        print(f"❌ Error fetching data from '{table_name}': {e}")
        return pd.DataFrame()

# ✅ Fetch data from tables
companies = fetch_data(
    "companies",
     filters={"status": ["trial", "active"]},
)
competitors = fetch_data(
    "competitors",
)
# Out:
# ✅ Successfully fetched `companies` table with filter '{'status': ['trial', 'active']}' and 6 rows.
# ✅ Successfully fetched `competitors` table with filter 'None' and 60 rows.

# %%
# Filter competitors to only trial accounts
filtered_competitors = competitors[competitors["company_id"].isin(companies["id"])]

# Optional: reset index if you want a clean one
filtered_competitors = filtered_competitors.reset_index(drop=True)
competitors = filtered_competitors
print(f"✅ Filtered to {len(companies)} trial accounts with {len(competitors)} competitors")
# Out:
# ✅ Filtered to 6 trial accounts with 26 competitors

# %% [markdown]
# # LinkedIn Feed

# %% [markdown]
# ## Search by keyword

# %%
# competitors = competitors[competitors["company_id"] == 73]
competitors
# Out:
#      id                        created_at  \
# 0    24  2025-02-07T16:02:05.586464+00:00
# 1   152  2025-12-01T20:26:58.956972+00:00
# 2    22  2025-01-27T16:36:50.780226+00:00
# 3    81  2025-08-12T18:48:23.719461+00:00
# 4    80  2025-08-12T18:48:23.589624+00:00
# 5   166  2026-01-17T21:49:52.466505+00:00
# 6   168  2026-01-17T21:49:53.054686+00:00
# 7   170  2026-01-22T22:20:29.682464+00:00
# 8   164  2026-01-17T21:49:51.804079+00:00
# 11  https://www.google.com/s2/favicons?domain=www....
# 12  https://www.google.com/s2/favicons?domain=www....
# 13  https://www.google.com/s2/favicons?domain=gobe...
# 14  https://www.google.com/s2/favicons?domain=serv...
# 15  https://www.google.com/s2/favicons?domain=hous...
# 16  https://www.google.com/s2/favicons?domain=wexi...
# 17  https://www.google.com/s2/favicons?domain=ambi...
# 18  https://www.google.com/s2/favicons?domain=www....
# 19  https://www.google.com/s2/favicons?domain=clay...
# 20  https://www.google.com/s2/favicons?domain=www....
# 21  https://www.google.com/s2/favicons?domain=micr...
# 22  https://www.google.com/s2/favicons?domain=nabl...
# 23  https://www.google.com/s2/favicons?domain=squa...
# 24  https://www.google.com/s2/favicons?domain=spot...
# 25  https://www.google.com/s2/favicons?domain=door...
#
#                               coresignal_api_response   facebook_id  \
# 0   {"id":12931125,"source_id":"33519287","company...  0.000000e+00
# 1   {"id":6068905,"source_id":"1028","company_name...           NaN
# 2   {"id":24236484,"source_id":"51650575","company...  1.535719e+14
# 3   {"id":1219335,"source_id":"10449851","company_...  0.000000e+00
# 4   {"id":11856286,"source_id":"17877435","company...  0.000000e+00
# 5   {"id":12588920,"source_id":"3794219","company_...  2.753236e+14
# 6   {"id":26634625,"source_id":"55054627","company...  0.000000e+00
# 7   {"id":2458006,"source_id":"5772","company_name...  3.639961e+14
# 8   {"id":10905323,"source_id":"10872551","company...  1.740011e+15
# 9   {"id":8103265,"source_id":"1617574","company_n...  1.836682e+14
# 10                                               None  0.000000e+00
# 11                                               None  0.000000e+00
# 12                                               None  0.000000e+00
# 13                   Failed to get details (HTTP 404)  0.000000e+00
# 14  {"id":9745982,"source_id":"3157549","company_n...  1.793177e+14
# 15  {"id":19346376,"source_id":"3491149","company_...  4.313816e+14
# 16  {"id":5893292,"source_id":"11637","company_nam...  1.222088e+14
# 17  {"id":82920325,"source_id":"77105967","company...  0.000000e+00
# 18  {"id":4475197,"source_id":"4335","company_name...  1.419405e+14
# 19  {"id":1824971,"source_id":"73731","company_nam...  1.681931e+14
# 20  {"id":23917548,"source_id":"163658","company_n...  0.000000e+00
# 21  {"id":5181133,"source_id":"1035","company_name...  0.000000e+00
# 22  {"id":12574483,"source_id":"28640609","company...  0.000000e+00
# 23                                               None  2.009258e+14
# 24                                               None  1.247614e+14
# 25                                               None  5.347542e+14
#
#              google_ads_id  linkedin_id  \
# 0   AR03382551659182817281            0
# 1                     None         1028
# 2   AR12657824252641148929            0
# 3                        0     10449851
# 4   AR04099081465491357697     17877435
# 5   AR18044909407396954113      3794219
# 6   AR16542392064705298433      5151868
# 7                     None         5772
# 8   AR12871690310899466241     10872551
# 9   AR07389967871058640897      1617574
# 10  AR03994400846061240321       166403
# 11  AR11345793554250203137        17354
# 12  AR04810561283612999681         9450
# 13  AR12478872043661557761    109914037
# 14  AR00871924403137413121      3157549
# 15  AR17264116582418743297      3491149
# 16  AR15861610164554563585        11637
# 17                       0     77105967
# 18  AR06850986051352133633         4335
# 19  AR12999362336941670401        73731
# 20  AR15066658739366920193       163658
# 21                       0     10065572
# 22  AR02425044569474203649     28640609
# 23  AR14896030700992987137       675562
# 24  AR07137559944517124097      1206743
# 25  AR00596762134998679553      3205573
#
#                                         custom_prompt  \
# 0   Hampr is an on-demand laundry service that con...
# 1   Oracle Health (formerly Cerner) is Oracle’s he...
# 2   HappyNest is a pickup and delivery laundry ser...
# 3   Pieces Technologies, Inc. (often just Pieces) ...
# 4   Suki is an AI-powered digital assistant design...
# 5   Workiz is a field service management software ...
# 6   Simply Wise (simplywise.com) is a financial te...
# 7   Turner Construction Company is a leading inter...
# 8   Field Pulse is a field service management soft...
# 9   Jobber is a cloud-based field service manageme...
# 10  The Rockefeller Foundation is a global philant...
# 11  Triodos Bank is a values-driven bank and impac...
# 12  Ashoka is a global social-impact organization ...
# 13  Best Mate is a company that appears to operate...
# 14  ServiceTitan is a cloud-based software platfor...
# 15  Housecall Pro is a software platform designed ...
# 16  Wex FSM (Fleet Solutions Management) is a divi...
# 17  Ambience Healthcare is a healthcare technology...
# 18  Skanska is a multinational construction and de...
# 19  Clayco is a full-service design-build firm spe...
# 20  Epic is the dominant electronic health record ...
# 21  Microsoft Healthcare refers specifically to Mi...
# 22  Nabla is a healthcare technology company that ...
# 23  Square (Block Inc.) is a multi-vertical commer...
# 24  SpotOn is a restaurant-focused POS provider th...
# 25  DoorDash is a leading delivery marketplace exp...
#
#                                     news_search_query
# 0   "hampr" laundry service OR "hampr" on-demand l...
# 1   ("Oracle Health" OR Cerner OR "Oracle healthca...
# 2   "HappyNest" laundry service OR "HappyNest" pic...
# 3   "Pieces Technologies" OR ("Pieces" AND (health...
# 4   "Suki" healthcare AI OR "Suki" voice assistant...
# 5   "Workiz" field service software OR "Workiz" se...
# 6   "Simply Wise" financial services OR "Simply Wi...
# 7   "Turner Construction" construction OR "Turner ...
# 8   "Field Pulse" field service management OR "Fie...
# 9   "Jobber" field service software OR "Jobber" bu...
# 10                                               None
# 11                                               None
# 12                                               None
# 13                          "Best Mate" field service
# 14  "Service Titan" field service software OR "Ser...
# 15  "Housecall Pro" field service software OR "Hou...
# 16  "Wex FSM" fleet management OR "Wex FSM" paymen...
# 17  "Ambience Healthcare" AI scribe OR "Ambience H...
# 18  "Skanska" construction OR "Skanska" infrastruc...
# 19  "Clayco" construction OR "Clayco" real estate ...
# 20                                               None
# 21  "Microsoft Healthcare" cloud services OR "Micr...
# 22  "Nabla" healthcare AI OR "Nabla" medical techn...
# 23  "Square" payment processing OR "Square" fintec...
# 24  "SpotOn" restaurant POS OR "SpotOn" payment pr...
# 25  "DoorDash" food delivery OR "DoorDash" restaur...

# %%
print("Starting linkedin feed keyword competitor search..")

API_URL = "https://professional-network-data.p.rapidapi.com/search-posts"
HEADERS = {
    "x-rapidapi-key": "e88f5d3d95msh96c8e7a091f4a90p1bee3cjsn2b537c4486ca",
    "x-rapidapi-host": "professional-network-data.p.rapidapi.com",
    "Content-Type": "application/json"
}

MAX_PAGES = 5
CONCURRENCY_LIMIT = 1

async def fetch_page(session, competitor_id, competitor_name, linkedin_id, page, sem, search_type):

    # Base payload
    payload = {
        "keyword": "",
        "sortBy": "date_posted",
        "datePosted": "pastWeek",
        "page": page,
        "contentType": "",
        "fromMember": [],
        "fromCompany": [],
        "mentionsMember": [],
        "mentionsOrganization": [],
        "authorIndustry": [],
        "authorCompany": [],
        "authorTitle": ""
    }

    # Apply OR logic via separate requests:
    if search_type == "mentions":
        payload["mentionsOrganization"] = [linkedin_id]
        payload["fromCompany"] = []
    elif search_type == "from_company":
        payload["fromCompany"] = [linkedin_id]
        payload["mentionsOrganization"] = []
    else:
        raise ValueError(f"Unknown search_type: {search_type}")

    async with sem:  # rate limit
        try:
            async with session.post(API_URL, json=payload, headers=HEADERS, timeout=30) as resp:
                data = await resp.json()
                posts = data.get("data", {}).get("items") or []

                if not posts:
                    print(f"No more posts for {competitor_name} [{search_type}] page {page}")
                    return []

                results = []
                for post in posts:
                    author = post.get("author") or {}
                    pics = author.get("profilePictures") or []
                    highest_res_pic = (
                        sorted(pics, key=lambda x: x.get("width", 0), reverse=True)[0]["url"]
                        if pics else None
                    )

                    results.append({
                        "competitor_id": competitor_id,
                        "competitor_name": competitor_name,
                        "search_type": search_type,
                        "text": post.get("text"),
                        "postUrl": post.get("url"),
                        "postedDate": post.get("postedDate"),
                        "author_id": author.get("id"),
                        "author_fullName": author.get("fullName"),
                        "author_username": author.get("username"),
                        "author_url": author.get("url"),
                        "headline": author.get("headline"),
                        "author_profile_pic": highest_res_pic,
                    })

                print(f"Processed {competitor_name} [{search_type}] page {page} — {len(posts)} posts")
                return results

        except Exception as e:
            print(f"❌ Error {competitor_name} [{search_type}] page {page}: {e}")
            return []


async def fetch_all_competitors():
    linkedin_posts = []
    sem = asyncio.Semaphore(CONCURRENCY_LIMIT)

    async with aiohttp.ClientSession() as session:
        tasks = []

        for _, row in competitors.iterrows():
            competitor_name = row["competitor_name"]
            competitor_id = int(row["id"])
            linkedin_id = row.get("linkedin_id")

            if not linkedin_id:
                print(f"Skipping {competitor_name} — no linkedin_id")
                continue

            for search_type in ("mentions", "from_company"):
                for page in range(1, MAX_PAGES + 1):
                    tasks.append(
                        fetch_page(
                            session=session,
                            competitor_id=competitor_id,
                            competitor_name=competitor_name,
                            linkedin_id=linkedin_id,
                            page=page,
                            sem=sem,
                            search_type=search_type,
                        )
                    )

        # Run everything concurrently
        results = await asyncio.gather(*tasks)

        # Flatten list-of-lists
        for batch in results:
            if batch:  # safety check
                linkedin_posts.extend(batch)

        return linkedin_posts


# run async function in Jupyter
linkedin_posts = await fetch_all_competitors()

linkedin_feed = pd.DataFrame(linkedin_posts)
print("Completed linkedin feed keyword competitor search..")
# Out:
# Starting linkedin feed keyword competitor search..
# Skipping hampr — no linkedin_id
# Skipping HappyNest — no linkedin_id
# Processed Oracle Health [mentions] page 1 — 10 posts
# Processed Oracle Health [mentions] page 2 — 10 posts
# Processed Oracle Health [mentions] page 3 — 10 posts
# Processed Oracle Health [mentions] page 4 — 10 posts
# Processed Oracle Health [mentions] page 5 — 10 posts
# Processed Oracle Health [from_company] page 1 — 10 posts
# Processed Oracle Health [from_company] page 2 — 2 posts
# No more posts for Oracle Health [from_company] page 3
# No more posts for Oracle Health [from_company] page 4
# No more posts for Oracle Health [from_company] page 5
# Processed Pieces [mentions] page 1 — 1 posts
# No more posts for Pieces [mentions] page 2
# No more posts for Pieces [mentions] page 3
# No more posts for Pieces [mentions] page 4
# No more posts for Pieces [mentions] page 5
# No more posts for Pieces [from_company] page 1
# No more posts for Pieces [from_company] page 2
# No more posts for Pieces [from_company] page 3
# No more posts for Pieces [from_company] page 4
# No more posts for Pieces [from_company] page 5
# Processed Suki [mentions] page 1 — 10 posts
# Processed Suki [mentions] page 2 — 5 posts
# No more posts for Suki [mentions] page 3
# No more posts for Suki [mentions] page 4
# No more posts for Suki [mentions] page 5
# Processed Suki [from_company] page 1 — 7 posts
# No more posts for Suki [from_company] page 2
# No more posts for Suki [from_company] page 3
# No more posts for Suki [from_company] page 4
# No more posts for Suki [from_company] page 5
# Processed Workiz [mentions] page 1 — 4 posts
# No more posts for Workiz [mentions] page 2
# No more posts for Workiz [mentions] page 3
# No more posts for Workiz [mentions] page 4
# No more posts for Workiz [mentions] page 5
# No more posts for Workiz [from_company] page 1
# No more posts for Workiz [from_company] page 2
# No more posts for Workiz [from_company] page 3
# No more posts for Workiz [from_company] page 4
# No more posts for Workiz [from_company] page 5
# No more posts for Simply Wise [mentions] page 1
# No more posts for Simply Wise [mentions] page 2
# No more posts for Simply Wise [mentions] page 3
# No more posts for Simply Wise [mentions] page 4
# No more posts for Simply Wise [mentions] page 5
# No more posts for Simply Wise [from_company] page 1
# No more posts for Simply Wise [from_company] page 2
# No more posts for Simply Wise [from_company] page 3
# ❌ Error Simply Wise [from_company] page 4: 'NoneType' object has no attribute 'get'
# No more posts for Simply Wise [from_company] page 5
# Processed Turner [mentions] page 1 — 10 posts
# Processed Turner [mentions] page 2 — 10 posts
# Processed Turner [mentions] page 3 — 10 posts
# Processed Turner [mentions] page 4 — 10 posts
# Processed Turner [mentions] page 5 — 10 posts
# Processed Turner [from_company] page 1 — 9 posts
# No more posts for Turner [from_company] page 2
# No more posts for Turner [from_company] page 3
# No more posts for Turner [from_company] page 4
# No more posts for Turner [from_company] page 5
# Processed Field Pulse [mentions] page 1 — 5 posts
# No more posts for Field Pulse [mentions] page 2
# No more posts for Field Pulse [mentions] page 3
# No more posts for Field Pulse [mentions] page 4
# No more posts for Field Pulse [mentions] page 5
# Processed Field Pulse [from_company] page 1 — 1 posts
# No more posts for Field Pulse [from_company] page 2
# No more posts for Field Pulse [from_company] page 3
# No more posts for Field Pulse [from_company] page 4
# No more posts for Field Pulse [from_company] page 5
# Processed Jobber [mentions] page 1 — 10 posts
# Processed Jobber [mentions] page 2 — 10 posts
# Processed Jobber [mentions] page 3 — 4 posts
# No more posts for Jobber [mentions] page 4
# No more posts for Jobber [mentions] page 5
# Processed Jobber [from_company] page 1 — 6 posts
# No more posts for Jobber [from_company] page 2
# No more posts for Jobber [from_company] page 3
# No more posts for Jobber [from_company] page 4
# No more posts for Jobber [from_company] page 5
# Processed The Rockefeller Foundation [mentions] page 1 — 10 posts
# Processed The Rockefeller Foundation [mentions] page 2 — 10 posts
# Processed The Rockefeller Foundation [mentions] page 3 — 10 posts
# Processed The Rockefeller Foundation [mentions] page 4 — 10 posts
# Processed The Rockefeller Foundation [mentions] page 5 — 10 posts
# Processed The Rockefeller Foundation [from_company] page 1 — 5 posts
# No more posts for The Rockefeller Foundation [from_company] page 2
# No more posts for The Rockefeller Foundation [from_company] page 3
# No more posts for The Rockefeller Foundation [from_company] page 4
# No more posts for The Rockefeller Foundation [from_company] page 5
# Processed Triodos [mentions] page 1 — 10 posts
# Processed Triodos [mentions] page 2 — 10 posts
# Processed Triodos [mentions] page 3 — 10 posts
# Processed Triodos [mentions] page 4 — 10 posts
# Processed Triodos [mentions] page 5 — 10 posts
# Processed Triodos [from_company] page 1 — 5 posts
# No more posts for Triodos [from_company] page 2
# No more posts for Triodos [from_company] page 3
# No more posts for Triodos [from_company] page 4
# No more posts for Triodos [from_company] page 5
# Processed Ashoka [mentions] page 1 — 10 posts
# Processed Ashoka [mentions] page 2 — 10 posts
# Processed Ashoka [mentions] page 3 — 10 posts
# Processed Ashoka [mentions] page 4 — 10 posts
# Processed Ashoka [mentions] page 5 — 10 posts
# Processed Ashoka [from_company] page 1 — 6 posts
# No more posts for Ashoka [from_company] page 2
# No more posts for Ashoka [from_company] page 3
# No more posts for Ashoka [from_company] page 4
# No more posts for Ashoka [from_company] page 5
# No more posts for Best Mate [mentions] page 1
# No more posts for Best Mate [mentions] page 2
# No more posts for Best Mate [mentions] page 3
# No more posts for Best Mate [mentions] page 4
# ❌ Error Best Mate [mentions] page 5: 'NoneType' object has no attribute 'get'
# Processed Best Mate [from_company] page 1 — 1 posts
# No more posts for Best Mate [from_company] page 2
# No more posts for Best Mate [from_company] page 3
# No more posts for Best Mate [from_company] page 4
# No more posts for Best Mate [from_company] page 5
# Processed Service Titan [mentions] page 1 — 10 posts
# Processed Service Titan [mentions] page 2 — 10 posts
# Processed Service Titan [mentions] page 3 — 10 posts
# Processed Service Titan [mentions] page 4 — 10 posts
# Processed Service Titan [mentions] page 5 — 10 posts
# Processed Service Titan [from_company] page 1 — 7 posts
# No more posts for Service Titan [from_company] page 2
# No more posts for Service Titan [from_company] page 3
# No more posts for Service Titan [from_company] page 4
# No more posts for Service Titan [from_company] page 5
# Processed Housecall Pro [mentions] page 1 — 10 posts
# Processed Housecall Pro [mentions] page 2 — 1 posts
# No more posts for Housecall Pro [mentions] page 3
# No more posts for Housecall Pro [mentions] page 4
# No more posts for Housecall Pro [mentions] page 5
# Processed Housecall Pro [from_company] page 1 — 2 posts
# No more posts for Housecall Pro [from_company] page 2
# No more posts for Housecall Pro [from_company] page 3
# No more posts for Housecall Pro [from_company] page 4
# No more posts for Housecall Pro [from_company] page 5
# Processed Wex FSM [mentions] page 1 — 10 posts
# Processed Wex FSM [mentions] page 2 — 10 posts
# Processed Wex FSM [mentions] page 3 — 10 posts
# Processed Wex FSM [mentions] page 4 — 5 posts
# No more posts for Wex FSM [mentions] page 5
# No more posts for Wex FSM [from_company] page 1
# No more posts for Wex FSM [from_company] page 2
# No more posts for Wex FSM [from_company] page 3
# No more posts for Wex FSM [from_company] page 4
# No more posts for Wex FSM [from_company] page 5
# Processed Ambience Healthcare [mentions] page 1 — 10 posts
# Processed Ambience Healthcare [mentions] page 2 — 10 posts
# Processed Ambience Healthcare [mentions] page 3 — 6 posts
# No more posts for Ambience Healthcare [mentions] page 4
# No more posts for Ambience Healthcare [mentions] page 5
# Processed Ambience Healthcare [from_company] page 1 — 7 posts
# No more posts for Ambience Healthcare [from_company] page 2
# No more posts for Ambience Healthcare [from_company] page 3
# No more posts for Ambience Healthcare [from_company] page 4
# No more posts for Ambience Healthcare [from_company] page 5
# Processed Skanksa [mentions] page 1 — 10 posts
# Processed Skanksa [mentions] page 2 — 10 posts
# Processed Skanksa [mentions] page 3 — 10 posts
# Processed Skanksa [mentions] page 4 — 10 posts
# Processed Skanksa [mentions] page 5 — 10 posts
# Processed Skanksa [from_company] page 1 — 10 posts
# ❌ Error Skanksa [from_company] page 2: 'NoneType' object has no attribute 'get'
# Processed Skanksa [from_company] page 3 — 10 posts
# Processed Skanksa [from_company] page 4 — 2 posts
# No more posts for Skanksa [from_company] page 5
# Processed Clayco [mentions] page 1 — 10 posts
# Processed Clayco [mentions] page 2 — 10 posts
# Processed Clayco [mentions] page 3 — 10 posts
# Processed Clayco [mentions] page 4 — 10 posts
# No more posts for Clayco [mentions] page 5
# Processed Clayco [from_company] page 1 — 4 posts
# No more posts for Clayco [from_company] page 2
# No more posts for Clayco [from_company] page 3
# No more posts for Clayco [from_company] page 4
# No more posts for Clayco [from_company] page 5
# Processed Epic [mentions] page 1 — 10 posts
# Processed Epic [mentions] page 2 — 10 posts
# Processed Epic [mentions] page 3 — 10 posts
# Processed Epic [mentions] page 4 — 10 posts
# Processed Epic [mentions] page 5 — 10 posts
# Processed Epic [from_company] page 1 — 2 posts
# No more posts for Epic [from_company] page 2
# No more posts for Epic [from_company] page 3
# No more posts for Epic [from_company] page 4
# No more posts for Epic [from_company] page 5
# Processed Microsoft Healthcare [mentions] page 1 — 10 posts
# Processed Microsoft Healthcare [mentions] page 2 — 10 posts
# Processed Microsoft Healthcare [mentions] page 3 — 1 posts
# No more posts for Microsoft Healthcare [mentions] page 4
# No more posts for Microsoft Healthcare [mentions] page 5
# Processed Microsoft Healthcare [from_company] page 1 — 1 posts
# ❌ Error Microsoft Healthcare [from_company] page 2: 'NoneType' object has no attribute 'get'
# No more posts for Microsoft Healthcare [from_company] page 3
# No more posts for Microsoft Healthcare [from_company] page 4
# No more posts for Microsoft Healthcare [from_company] page 5
# Processed Nabla [mentions] page 1 — 10 posts
# Processed Nabla [mentions] page 2 — 10 posts
# Processed Nabla [mentions] page 3 — 10 posts
# Processed Nabla [mentions] page 4 — 5 posts
# No more posts for Nabla [mentions] page 5
# Processed Nabla [from_company] page 1 — 1 posts
# No more posts for Nabla [from_company] page 2
# No more posts for Nabla [from_company] page 3
# No more posts for Nabla [from_company] page 4
# No more posts for Nabla [from_company] page 5
# Processed Square [mentions] page 1 — 10 posts
# Processed Square [mentions] page 2 — 10 posts
# Processed Square [mentions] page 3 — 10 posts
# Processed Square [mentions] page 4 — 10 posts
# Processed Square [mentions] page 5 — 10 posts
# Processed Square [from_company] page 1 — 6 posts
# No more posts for Square [from_company] page 2
# No more posts for Square [from_company] page 3
# No more posts for Square [from_company] page 4
# No more posts for Square [from_company] page 5
# Processed SpotOn [mentions] page 1 — 10 posts
# Processed SpotOn [mentions] page 2 — 10 posts
# Processed SpotOn [mentions] page 3 — 1 posts
# No more posts for SpotOn [mentions] page 4
# No more posts for SpotOn [mentions] page 5
# Processed SpotOn [from_company] page 1 — 8 posts
# No more posts for SpotOn [from_company] page 2
# No more posts for SpotOn [from_company] page 3
# No more posts for SpotOn [from_company] page 4
# No more posts for SpotOn [from_company] page 5
# Processed DoorDash [mentions] page 1 — 10 posts
# Processed DoorDash [mentions] page 2 — 10 posts
# Processed DoorDash [mentions] page 3 — 10 posts
# Processed DoorDash [mentions] page 4 — 10 posts
# Processed DoorDash [mentions] page 5 — 10 posts
# Processed DoorDash [from_company] page 1 — 7 posts
# No more posts for DoorDash [from_company] page 2
# No more posts for DoorDash [from_company] page 3
# No more posts for DoorDash [from_company] page 4
# ❌ Error DoorDash [from_company] page 5: 'NoneType' object has no attribute 'get'
# Completed linkedin feed keyword competitor search..

# %%
linkedin_feed.head(50)
# Out:
#     competitor_id competitor_name search_type  \
# 0             152   Oracle Health    mentions
# 1             152   Oracle Health    mentions
# 2             152   Oracle Health    mentions
# 3             152   Oracle Health    mentions
# 4             152   Oracle Health    mentions
# 5             152   Oracle Health    mentions
# 6             152   Oracle Health    mentions
# 7             152   Oracle Health    mentions
# 8             152   Oracle Health    mentions
# 9             152   Oracle Health    mentions
# 10            152   Oracle Health    mentions
# 11            152   Oracle Health    mentions
# 12            152   Oracle Health    mentions
# 13            152   Oracle Health    mentions
# 14            152   Oracle Health    mentions
# 15            152   Oracle Health    mentions
# 16            152   Oracle Health    mentions
# 17            152   Oracle Health    mentions
# 18            152   Oracle Health    mentions
# 19            152   Oracle Health    mentions
# 20            152   Oracle Health    mentions
# 21            152   Oracle Health    mentions
# 22            152   Oracle Health    mentions
# 23            152   Oracle Health    mentions
# 24            152   Oracle Health    mentions
# 25            152   Oracle Health    mentions
# 26            152   Oracle Health    mentions
# 27            152   Oracle Health    mentions
# 28            152   Oracle Health    mentions
# 29            152   Oracle Health    mentions
# 30            152   Oracle Health    mentions
# 31            152   Oracle Health    mentions
# 32            152   Oracle Health    mentions
# 33            152   Oracle Health    mentions
# 34            152   Oracle Health    mentions
# 35            152   Oracle Health    mentions
# 36            152   Oracle Health    mentions
# 37            152   Oracle Health    mentions
# 38            152   Oracle Health    mentions
# 39            152   Oracle Health    mentions
# 40            152   Oracle Health    mentions
# 41            152   Oracle Health    mentions
# 42            152   Oracle Health    mentions
# 43            152   Oracle Health    mentions
# 44            152   Oracle Health    mentions
# 45            152   Oracle Health    mentions
# 46            152   Oracle Health    mentions
# 47            152   Oracle Health    mentions
# 48            152   Oracle Health    mentions
# 49            152   Oracle Health    mentions
#
#                                                  text  \
# 0   Organizations that are deploying specialized A...
# 1   Why the "AI Bubble" debate is asking the wrong...
# 2   ✨ This week, we’re celebrating 25 years of Mot...
# 3   Hi everyone! 👋\n\nI am currently seeking remot...
# 4   I got a kick of inspiration last week while in...
# 5   ¡Hola! ✨\nDespués de algunos meses ha terminad...
# 6   Organizations that are deploying specialized A...
# 7   #Feb092026 #0320pmEST\n\n#From : Dean V. Reich...
# 8   Hi everyone! 👋\n\nI am currently seeking remot...
# 9   Discover the future of AI at #AIWorld Tour Abu...
# 10  Lors du #AIWorld Tour Paris le 19 mars, Steve ...
# 11  Organizations that are deploying specialized A...
# 12  Delayed. Over budget. Again? You're not alone....
# 13  Estão abertas as inscrições para o Geração Cal...
# 14  A few weeks ago, I participated in Hofstra Uni...
# 15  🚀 Excited to be back on the Sales Campus Recru...
# 16  Stop keeping up. Start setting the pace. Join ...
# 17  Oracle & Microsoft ✅ \nOracle AI Database  & M...
# 18  Have you been watching the X-Files show 𝐥̶𝐚̶𝐭̶...
# 19  As a freshman, I used to see schools like UT A...
# 20  Organizations that are deploying specialized A...
# 21  Organizations that are deploying specialized A...
# 22  Hemos vuelto con nuestras sesiones de IA en #O...
# 23  #09Feb2026 #0204pm\n\n#From: Dean V. Reich.  C...
# 24  Learn how to seamlessly access the same data w...
# 25  The pace of AI innovation is accelerating. Are...
# 26  My second time at Web Summit Qatar 2026 was ev...
# 27  𝐀𝐥𝐩𝐡𝐚𝐛𝐞𝐭’𝐬 𝐁𝐨𝐧𝐝 𝐒𝐚𝐥𝐞 𝐏𝐮𝐥𝐥𝐬 𝐈𝐧 𝐎𝐯𝐞𝐫 $𝟏𝟎𝟎 𝐁𝐢𝐥𝐥𝐢𝐨...
# 28  We are proud to support the delivery of a tran...
# 29  Oracle Red Bull Racing & Red Bull Technology i...
# 30  Organizations that are deploying specialized A...
# 31  Discover how to drive real value for your orga...
# 32  Seguimos acercando a los jóvenes de Fundación ...
# 33  I'm happy to share that I've earned a new cert...
# 34  As technology moves faster and faster, what ha...
# 35  Open Invitation to Global Tech Leaders: Join U...
# 36  Las organizaciones que implementan agentes de ...
# 37  O AI Tinkerers SP, representado pelos seus emb...
# 38  Not every day you have the CEO in the office 😎...
# 39  From visibility to credibility—powered by infl...
# 40  I’m happy to share that I’ve obtained a new ce...
# 41  Last week, we announced Frontier - a new platf...
# 42  I’m looking forward to being part of this sess...
# 43  Stop keeping up. Start setting the pace. Join ...
# 44  Hola!\nHace unos días termino el Hackaton orga...
# 45  Organizations that are deploying specialized A...
# 46  Organizations that are deploying specialized A...
# 47  Stop keeping up. Start setting the pace. Join ...
# 48  Maximize your data, wherever it lives. Join Or...
# 49  Que orgulho ver nossa cliente Claro Brasil se ...
#
#                                               postUrl  \
# 0   https://www.linkedin.com/posts/kirk-a-frailey-...
# 6                                    Christina Kupec
# 7                            Dean V. Reich. CNBI LLC
# 8                                 Carlo Micco Olalia
# 9                                  Elie Yasmine, MBA
# 10                                 Elie Yasmine, MBA
# 11                                 Elie Yasmine, MBA
# 12                                  Anthony Abinader
# 13                                   Igor Thomé Rosa
# 14                                   Samantha Nadler
# 15                        Danielle Deneroff, SHRM-TA
# 16                                 Tina Hull Buehler
# 17                          Jesper Kongsdal Sørensen
# 18                                  Dorota Kozlowska
# 19                                     Temple Joseph
# 20                                         Gilson M.
# 21                         Valentin Leonard Tabacaru
# 22                          Andres Huenulaf Sandoval
# 23                           Dean V. Reich. CNBI LLC
# 24                                     David Johnson
# 25                                    Janette Coslop
# 26  Mohammad Albow EMBA HEC Paris, PMP, RMP-PMI, VMA
# 27                                          Cliff R.
# 28                       CMC Project Solutions, Inc.
# 29                                      Rui Romanini
# 30                             Theresa Marie Haddock
# 31                                       Greta R. L.
# 32                          Alejandra Barcenas Ortiz
# 33                   Juan Carlos Domínguez Hernández
# 34                                           Mythics
# 35            Hamada Rida (PMP®, PSPO®) Open to work
# 36                               GONZALO PÉREZ RUBIO
# 37                                   AI Tinkerers SP
# 38                               Carolina Diaz Serna
# 39                                Mukesh Tanwar, MBA
# 40                                         Madhu Ray
# 41                               OpenAI for Business
# 42                                    Kevin Chowning
# 43                                    Joseph Sheehan
# 44                       Lorena Maria Raygoza Ibarra
# 45                                    Clare Atkinson
# 46                                     Allison Salke
# 47                                  Jonathan Beasley
# 48                                   Tony Obergefell
# 49                                 Alexandre Maioral
#
#                                   author_username  \
# 0                           kirk-a-frailey-6b1459
# 1                     jeremy-sullivan-jp-aab87020
# 2                                         motivcx
# 3                                olaliacarlomicco
# 4                                   mickelibedore
# 5                                lorena-raygoza09
# 6                          christina-kupec-51a727
# 7                 dean-v-reich-cnbi-llc-b9425b212
# 8                                olaliacarlomicco
# 9                       elie-yasmine-mba-16b70b22
# 10                      elie-yasmine-mba-16b70b22
# 11                      elie-yasmine-mba-16b70b22
# 12                                    antabinader
# 13                                     igor-thomé
# 14                                       sknadler
# 15                               danielledeneroff
# 16                      tina-hull-buehler-7685995
# 17                              jespersoerensendk
# 18                               dorota-kozlowska
# 19                                       temple23
# 20                                     gilsonmelo
# 21                                 valentinoracle
# 22                          andreshuenulaf-edtech
# 23                dean-v-reich-cnbi-llc-b9425b212
# 24                                     davidj2403
# 25                                  janettecoslop
# 26                                 mohammad-albow
# 27                                      cliffbray
# 28                      cmc-project-solutions-inc
# 29                          rui-romanini-89410133
# 30                            theresamariehaddock
# 31                                   gretarlamont
# 32              alejandra-barcenas-ortiz-12bab052
# 33      juan-carlos-domínguez-hernández-100597193
# 34                                        mythics
# 35  hamada-rida-pmp®-pspo®-open-to-work-a70522215
# 36                              gonzalopérezrubio
# 37                                ai-tinkerers-sp
# 38                            carolina-diaz-serna
# 39                                       0riginal
# 40                            madhu-ray-5037a12a2
# 41                            openai-for-business
# 42                         kevin-chowning-a422b88
# 43                        joseph-sheehan-29704842
# 44                               lorena-raygoza09
# 4                  I help software engineers level up
# 5   Desarrolladora Jr. | HTML | CSS | Javascript |...
# 6                  MBA, Solutions Architect at Oracle
# 7   CNBI LLC . Consultant | Homeland Security LEO’...
# 8   Localization Project Manager (PMP Basic Certif...
# 9   Sales Director, Digital BSS & Cloud Solutions ...
# 10  Sales Director, Digital BSS & Cloud Solutions ...
# 11  Sales Director, Digital BSS & Cloud Solutions ...
# 12  Construction & Engineering - Industry Strategy...
# 13  Junior Cybersecurity Analyst & Developer (Java...
# 14  Honors 4+1 CS and Math / Data Science Student ...
# 15    Senior University Campus Recruiter @ Oracle ☁️💻
# 16                     Alliances Consultant at Oracle
# 17  CEO I CCO I Sales Executive I Boardmember I In...
# 18  Award Winning Keynote Speaker | Penetration Te...
# 19  Prev @Eaton | Cyber Major @UTSA & NSBE Finance...
# 20  Global Multicloud & Customer Success Leader | ...
# 21  Senior Principal Product Manager – Database Pl...
# 22  EdTech Sales Leader | Driving Digital Transfor...
# 23  CNBI LLC . Consultant | Homeland Security LEO’...
# 24  Helping Strategic Partners Improve Business Ef...
# 25             Senior Manager, Oracle Talent Advisory
# 26  Project Manager | Senior Procurement & Contrac...
# 27  Featured in LinkedIn News | Executive Strategi...
# 28                                    1,210 followers
# 29                       AI Engineer / Data Scientist
# 30  Lead Operational Revenue Cycle Architect at Or...
# 31  Executive Assistant @ Oracle | Managing Comple...
# 32                                   Politóloga y MAP
# 33  Cloud Engineer | IA Engineer | AWS | Oracle | ...
# 34                                   11,421 followers
# 35  Contributing Member, 451 Alliance S&P Global |...
# 36  Telco Tech Manager for Strategic Accounts Cent...
# 37                                      558 followers
# 38  Cloud & AI Account Manager @ Oracle - Public S...
# 39  Entrepreneur | Mentor | Founder | Managing Dir...
# 40  Supply Chain Management | Digital Product Mana...
# 41                                  374,520 followers
# 42  Helping healthcare organizations modernize and...
# 43  Regional Account Executive specializing in Dat...
# 44  Desarrolladora Jr. | HTML | CSS | Javascript |...
# 45  Providing Innovative business solutions for th...
# 46               Product Marketing @ Oracle Utilities
# 47  Strategic Advisor, Healthcare and Life Science...
# 48  Senior Cloud Data Platform and Multicloud Repr...
# 49    President at Oracle Brazil | LinkedIn Top Voice
#
#                                    author_profile_pic
# 0   https://media.licdn.com/dms/image/v2/C4E03AQFT...
# 1   https://media.licdn.com/dms/image/v2/D5603AQHG...
# 2   https://media.licdn.com/dms/image/v2/D560BAQG7...
# 3   https://media.licdn.com/dms/image/v2/D5635AQHM...
# 4   https://media.licdn.com/dms/image/v2/D5603AQF5...
# 5   https://media.licdn.com/dms/image/v2/D4E03AQGk...
# 6                                                None
# 7   https://media.licdn.com/dms/image/v2/D5603AQHq...
# 8   https://media.licdn.com/dms/image/v2/D5635AQHM...
# 9   https://media.licdn.com/dms/image/v2/D4E03AQH0...
# 10  https://media.licdn.com/dms/image/v2/D4E03AQH0...
# 11  https://media.licdn.com/dms/image/v2/D4E03AQH0...
# 12  https://media.licdn.com/dms/image/v2/D5603AQF9...
# 13  https://media.licdn.com/dms/image/v2/D4D03AQE6...
# 14  https://media.licdn.com/dms/image/v2/D4E03AQFK...
# 15  https://media.licdn.com/dms/image/v2/D4E03AQFg...
# 16  https://media.licdn.com/dms/image/v2/C4E03AQGW...
# 17                                               None
# 18                                               None
# 19  https://media.licdn.com/dms/image/v2/D5603AQGp...
# 20  https://media.licdn.com/dms/image/v2/D5603AQEI...
# 21  https://media.licdn.com/dms/image/v2/D4D03AQFb...
# 22  https://media.licdn.com/dms/image/v2/D4E03AQEd...
# 23  https://media.licdn.com/dms/image/v2/D5603AQHq...
# 24  https://media.licdn.com/dms/image/v2/C5603AQFi...
# 25  https://media.licdn.com/dms/image/v2/C4D03AQFC...
# 26  https://media.licdn.com/dms/image/v2/D4D03AQEw...
# 27  https://media.licdn.com/dms/image/v2/D5603AQEg...
# 28  https://media.licdn.com/dms/image/v2/D560BAQHm...
# 29                                               None
# 30  https://media.licdn.com/dms/image/v2/D5603AQFQ...
# 31                                               None
# 32  https://media.licdn.com/dms/image/v2/D4E03AQHF...
# 33  https://media.licdn.com/dms/image/v2/D4E35AQFr...
# 34  https://media.licdn.com/dms/image/v2/D4E0BAQHw...
# 35                                               None
# 36  https://media.licdn.com/dms/image/v2/D4E03AQG2...
# 37  https://media.licdn.com/dms/image/v2/D4D0BAQEG...
# 38  https://media.licdn.com/dms/image/v2/D4D03AQEa...
# 39  https://media.licdn.com/dms/image/v2/D5603AQFH...
# 40                                               None
# 41  https://media.licdn.com/dms/image/v2/D560BAQHh...
# 42                                               None
# 43  https://media.licdn.com/dms/image/v2/C5603AQG4...
# 44  https://media.licdn.com/dms/image/v2/D4E03AQGk...
# 45                                               None
# 46                                               None
# 47                                               None
# 48  https://media.licdn.com/dms/image/v2/C4D03AQFZ...
# 49  https://media.licdn.com/dms/image/v2/D4D03AQHc...

# %% [markdown]
# ## Send data back to supabase

# %%
# Remove trailing " UTC"
linkedin_feed['postedDate'] = pd.to_datetime(
    linkedin_feed['postedDate'].str.replace(" UTC", "", regex=False),
    format='mixed',
    errors='coerce'
).dt.date.astype(str)

# Convert to datetime and extract date as string in YYYY-MM-DD format
linkedin_feed['postedDate'] = pd.to_datetime(linkedin_feed['postedDate']).dt.date.astype(str)

# %%
# 1. Remove duplicates in-memory before upsert
linkedin_feed = linkedin_feed.drop_duplicates(subset=["postUrl"], keep="last")

rows = []
for _, row in linkedin_feed.iterrows():
    rows.append({
        "author_id": int(row["author_id"]) if pd.notna(row["author_id"]) else None,
        "author_fullName": row.get("author_fullName"),
        "author_profile_pic": row.get("author_profile_pic"),
        "postUrl": row.get("postUrl"),
        "headline": row.get("headline"),
        "author_url": row.get("author_url"),
        "text": row.get("text"),
        "postedDate": row.get("postedDate"),
        "competitor_id": int(row["competitor_id"]) if pd.notna(row["competitor_id"]) else None,
    })

# 2. Upsert batch
response = supabase.table("linkedin_feed").upsert(
    rows,
    on_conflict="postUrl"
).execute()

count = len(response.data) if response.data else 0
print(f"Upsert complete — {count} rows inserted/updated")
# Out:
# Upsert complete — 848 rows inserted/updated
